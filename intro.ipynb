# %% [markdown]
# ### Libraries we'll use

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')

# %%
# download the data of the stock
Apple = yf.download('AAPL', start='2010-01-01', end='2021-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.478997
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.490199
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.386964
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.375158
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.417541
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  129.679718
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.317841
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  132.529388
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.399368
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  130.387253
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# 2010-01-07  477131200
# 2010-01-08  447610800
# ...               ...
# 2020-12-24   54930100
# 2020-12-28  124486200
# 2020-12-29  121047300
# 2020-12-30   96452100
# 2020-12-31   99116600
#
# [2769 rows x 6 columns]

# %%
ticker = ['SPY', 'AAPL', 'KO']

# %%
stocks = yf.download(ticker, start='2010-01-01', end='2021-01-01')
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.478997  18.498016   87.129959    7.643214  28.520000
# 2010-01-05    6.490199  18.274246   87.360603    7.656429  28.174999
# 2010-01-06    6.386964  18.267769   87.422096    7.534643  28.165001
# 2010-01-07    6.375158  18.222364   87.791122    7.520714  28.094999
# 2010-01-08    6.417541  17.885094   88.083252    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.679718  48.779106  352.968048  131.970001  53.439999
# 2020-12-28  134.317841  49.436306  356.000336  136.690002  54.160000
# 2020-12-29  132.529388  49.408932  355.321136  134.869995  54.130001
# 2020-12-30  131.399368  49.691891  355.828186  133.720001  54.439999
# 2020-12-31  130.387253  50.057003  357.636047  132.690002  54.840000
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04  113.330002    7.660714  28.610001  113.389999    7.585000
# 2010-01-05  113.629997    7.699643  28.495001  113.680000    7.616071
# 2010-01-06  113.709999    7.686786  28.219999  113.989998    7.526786
# 2010-01-07  114.190002    7.571429  28.184999  114.330002    7.466071
# 2010-01-08  114.570000    7.571429  27.820000  114.620003    7.466429
# ...                ...         ...        ...         ...         ...
# 2020-12-24  369.000000  133.460007  53.549999  369.029999  131.100006
# 2020-12-28  372.170013  137.339996  54.439999  372.589996  133.509995
# 2020-12-29  371.459991  138.789993  54.490002  374.000000  134.339996
# 2020-12-30  371.989990  135.990005  54.630001  373.100006  133.399994
# 2020-12-31  373.880005  134.740005  54.930000  374.660004  131.720001
columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2769 non-null   float64
#  1   (Adj Close, KO)    2769 non-null   float64
#  2   (Adj Close, SPY)   2769 non-null   float64
#  3   (Close, AAPL)      2769 non-null   float64
#  4   (Close, KO)        2769 non-null   float64
#  5   (Close, SPY)       2769 non-null   float64
#  6   (High, AAPL)       2769 non-null   float64
#  7   (High, KO)         2769 non-null   float64
#  8   (High, SPY)        2769 non-null   float64
#  9   (Low, AAPL)        2769 non-null   float64
#  10  (Low, KO)          2769 non-null   float64
#  11  (Low, SPY)         2769 non-null   float64
#  12  (Open, AAPL)       2769 non-null   float64
#  13  (Open, KO)         2769 non-null   float64
#  14  (Open, SPY)        2769 non-null   float64
#  15  (Volume, AAPL)     2769 non-null   int64
#  16  (Volume, KO)       2769 non-null   int64
#  17  (Volume, SPY)      2769 non-null   int64
# dtypes: float64(15), int64(3)
# memory usage: 411.0 KB

# %%
# stocks.to_csv('stocks.csv')

# %%
# stocks = pd.read_csv('stocks.csv', header=[0,1], index_col=0, parse_dates=[0])
# stocks

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
# convertir multi indice a tupla

stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks.head()
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2010-01-04           6.478997        18.498016         87.129959
# 2010-01-05           6.490199        18.274246         87.360603
# 2010-01-06           6.386964        18.267769         87.422096
# 2010-01-07           6.375158        18.222364         87.791122
# 2010-01-08           6.417541        17.885094         88.083252
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# 2010-01-05       7.656429    28.174999    113.629997      7.699643
# 2010-01-06       7.534643    28.165001    113.709999      7.686786
# 2010-01-07       7.520714    28.094999    114.190002      7.571429
# 2010-01-08       7.570714    27.575001    114.570000      7.571429
#
#             (High, KO)  (High, SPY)  (Low, AAPL)  (Low, KO)  (Low, SPY)  \
# Date
# %%
close = stocks.loc[:,'Close'].copy()

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
close.plot(figsize=(8,5), fontsize=10)
plt.show()

# %% [markdown]
# ### Normalize values

# %%
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2020-12-24    1726.629626
# 2020-12-28    1788.383766
# 2020-12-29    1764.571699
# 2020-12-30    1749.525753
# 2020-12-31    1736.049763
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL      7.643214
# KO       28.520000
# SPY     113.330002
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(8,5), fontsize=10)
plt.show()

# %%
aapl = close.AAPL.copy().to_frame()
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2020-12-24  130.960007
# 2020-12-28  131.970001
# 2020-12-29  136.690002
# 2020-12-30  134.869995
# 2020-12-31  133.720001
#
# [2769 rows x 1 columns]

# %%
aapl['lag1'] = aapl.shift(periods=1)
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2769 rows x 2 columns]

# %%
aapl['diff'] = aapl.AAPL.sub(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1      diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2020-12-24  131.970001  130.960007  1.009995
# 2020-12-28  136.690002  131.970001  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999
#
# [2769 rows x 3 columns]

# %%
aapl['% change'] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
aapl
# Out:
#                   AAPL        lag1      diff  % change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265
#
# [2769 rows x 4 columns]

# %%
aapl.AAPL.resample('M').last()
# Out:
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-31    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: M, Name: AAPL, Length: 132, dtype: float64

# %%
aapl.AAPL.resample('BM').last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2020-08-31    21.437974
# 2020-09-30   -10.252632
# 2020-10-30    -6.001206
# 2020-11-30     9.360649
# 2020-12-31    11.457370
# Freq: BM, Name: AAPL, Length: 132, dtype: float64

# %%
aapl
del aapl['lag1']
del aapl['% change']
del aapl['diff']

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna()
ret
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008821
# ...              ...
# 2020-12-24  0.007712
# 2020-12-28  0.035766
# 2020-12-29 -0.013315
# 2020-12-30 -0.008527
# 2020-12-31 -0.007703
#
# [2768 rows x 1 columns]

# %%
ret.plot(kind='hist', figsize=(8,5), fontsize=8, bins=100)
plt.show()

# %%
daily_mean_return = ret.mean()
print(f'daily return:{daily_mean_return}')

var_daily = ret.var()
print(f'daily variance:{var_daily}')

daily_std = np.sqrt(var_daily)
print(f'daily standard deviation:{daily_std}')
# Out:
# daily return:AAPL    0.001191
# dtype: float64
# daily variance:AAPL    0.000318
# dtype: float64
# daily standard deviation:AAPL    0.017843
# dtype: float64

# %%
annual_mean_return = daily_mean_return * 252
annual_mean_return
# Out:
# AAPL    0.300134
# dtype: float64

# %%
annual_var_return = var_daily * 252
annual_var_return
# Out:
# AAPL    0.080226
# dtype: float64

# %%
annual_std_return = np.sqrt(annual_var_return)
annual_std_return
# Out:
# AAPL    0.283242
# dtype: float64

# %%
ticker = ['AAPL', 'KO', 'SPY', 'TSLA', 'MSFT', 'NVDA']
stocks = yf.download(ticker, start='2010-01-01', end='2021-01-01')
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
close = stocks.loc[:, 'Close'].copy()

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(8,5), fontsize=8)
plt.legend(fontsize=8)
plt.show()

# %% [markdown]
# ### Risk / Reward stocks

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL        KO      MSFT      NVDA       SPY      TSLA
# Date
# 2010-06-30 -0.018113 -0.004173 -0.012870 -0.025763 -0.009500 -0.002511
# 2010-07-01 -0.012126 -0.001796  0.006519  0.016650 -0.004456 -0.078473
# 2010-07-02 -0.006198  0.000400  0.004750 -0.012524 -0.005450 -0.125683
# 2010-07-06  0.006844  0.007592  0.023636 -0.010732  0.006556 -0.160937
# 2010-07-07  0.040381  0.020623  0.020151  0.048323  0.031496 -0.019243

# %%
ret.describe()
# Out:
#               AAPL           KO         MSFT         NVDA          SPY  \
# count  2646.000000  2646.000000  2646.000000  2646.000000  2646.000000
# mean      0.001169     0.000356     0.000982     0.001830     0.000542
# std       0.017736     0.011062     0.016050     0.026627     0.010811
# min      -0.128647    -0.096725    -0.147390    -0.187559    -0.109424
# 25%      -0.007022    -0.004628    -0.006686    -0.010929    -0.003468
# 50%       0.000887     0.000447     0.000683     0.001450     0.000632
# 75%       0.010251     0.005703     0.008726     0.014195     0.005409
# max       0.119808     0.064796     0.142169     0.298067     0.090603
#
#               TSLA
# count  2646.000000
# mean      0.002515
# std       0.035483
# min      -0.210628
# 25%      -0.014807
# 50%       0.001179
# 75%       0.019164
# max       0.243951

# %%
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  2646.0  0.001169  0.017736 -0.128647 -0.007022  0.000887  0.010251
# KO    2646.0  0.000356  0.011062 -0.096725 -0.004628  0.000447  0.005703
# MSFT  2646.0  0.000982  0.016050 -0.147390 -0.006686  0.000683  0.008726
# NVDA  2646.0  0.001830  0.026627 -0.187559 -0.010929  0.001450  0.014195
# SPY   2646.0  0.000542  0.010811 -0.109424 -0.003468  0.000632  0.005409
# TSLA  2646.0  0.002515  0.035483 -0.210628 -0.014807  0.001179  0.019164
#
#            max
# AAPL  0.119808
# KO    0.064796
# MSFT  0.142169
# NVDA  0.298067
# SPY   0.090603
# TSLA  0.243951

# %%
summary = ret.describe().T.loc[:, ['mean','std']]
summary
# Out:
#           mean       std
# AAPL  0.001169  0.017736
# KO    0.000356  0.011062
# MSFT  0.000982  0.016050
# NVDA  0.001830  0.026627
# SPY   0.000542  0.010811
# TSLA  0.002515  0.035483

# %%
summary['mean'] = summary['mean'] * 252
summary['std'] = summary['std'] * np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.294517  0.281558
# KO    0.089689  0.175611
# MSFT  0.247365  0.254779
# NVDA  0.461055  0.422684
# SPY   0.136493  0.171613
# TSLA  0.633755  0.563280

# %%
summary.plot(kind='scatter', x='std', y='mean', figsize=(10,8), s=30, fontsize=8)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, 'std'] + 0.005, summary.loc[i, 'mean'] + 0.005), size=10)
plt.xlabel('Annual risk (std)', fontsize=10)
plt.ylabel('Annual return', fontsize=10)
plt.title('Risk/Return', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Risk/Return')

# %% [markdown]
# ### Correlation and Covariance

# %%
ret.cov()
# Out:
#           AAPL        KO      MSFT      NVDA       SPY      TSLA
# AAPL  0.000315  0.000066  0.000157  0.000217  0.000126  0.000191
# KO    0.000066  0.000122  0.000076  0.000079  0.000077  0.000079
# MSFT  0.000157  0.000076  0.000258  0.000227  0.000129  0.000182
# NVDA  0.000217  0.000079  0.000227  0.000709  0.000170  0.000295
# SPY   0.000126  0.000077  0.000129  0.000170  0.000117  0.000150
# TSLA  0.000191  0.000079  0.000182  0.000295  0.000150  0.001259

# %%
ret.corr()
# Out:
#           AAPL        KO      MSFT      NVDA       SPY      TSLA
# AAPL  1.000000  0.335196  0.550272  0.459368  0.655058  0.303077
# KO    0.335196  1.000000  0.426286  0.268788  0.641213  0.202281
# MSFT  0.550272  0.426286  1.000000  0.531245  0.744590  0.319943
# NVDA  0.459368  0.268788  0.531245  1.000000  0.590393  0.311747
# SPY   0.655058  0.641213  0.744590  0.590393  1.000000  0.390451
# TSLA  0.303077  0.202281  0.319943  0.311747  0.390451  1.000000

# %%
import seaborn as sns

plt.figure(figsize=(8,5))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap='flare', annot=True, annot_kws={'size':10}, vmax=0.6)
plt.show()

# %% [markdown]
# ### Simple returns and log returns

# %%
df = pd.DataFrame(index=[2016, 2017, 2018], data=[100, 50, 95], columns=['Price'])
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns = df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
100*1.2*1.2
# Out:
# 144.0

# %%
# mean returns are misleading

# %%
logreturns = np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %% [markdown]
# ### Simple moving average

# %%
SPY = yf.download('SPY')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy = SPY.Close.to_frame()

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-12-22  473.649994
# 2023-12-26  475.649994
# 2023-12-27  476.510010
# 2023-12-28  476.690002
# 2023-12-29  475.309998
#
# [7786 rows x 1 columns]

# %%
spy.plot(figsize=(8,5), fontsize=(10))
plt.legend(loc='upper left', fontsize=10)
plt.show()

# %%
spy_roll = spy.rolling(window=10)

# %%
spy_roll = spy_roll.mean()

# %%
spy_roll.head(15) # nan porque el moving average necesita dias anteriores
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875

# %%
spy.rolling(window=10).median()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-12-22  471.235001
# 2023-12-26  471.990005
# 2023-12-27  472.355011
# 2023-12-28  473.175003
# 2023-12-29  474.244995
#
# [7786 rows x 1 columns]

# %%
spy.rolling(window=10, min_periods=5).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04   45.000000
# ...                ...
# 2023-12-22  474.839996
# 2023-12-26  475.649994
# 2023-12-27  476.510010
# 2023-12-28  476.690002
# 2023-12-29  476.690002
#
# [7786 rows x 1 columns]

# %%
spy.rolling(window=10, min_periods=5).min().head(15)
# Out:
#                Close
# Date
# 1993-01-29       NaN
# 1993-02-01       NaN
# 1993-02-02       NaN
# 1993-02-03       NaN
# 1993-02-04  43.93750
# 1993-02-05  43.93750
# 1993-02-08  43.93750
# 1993-02-09  43.93750
# 1993-02-10  43.93750
# 1993-02-11  43.93750
# 1993-02-12  44.25000
# 1993-02-16  43.46875
# 1993-02-17  43.43750
# 1993-02-18  43.40625
# 1993-02-19  43.40625

# %%
spy['SMA50'] = spy.rolling(window=50, min_periods=50).mean()

# %%
spy.head(52)
# Out:
#                Close     SMA50
# Date
# 1993-01-29  43.93750       NaN
# 1993-02-01  44.25000       NaN
# 1993-02-02  44.34375       NaN
# 1993-02-03  44.81250       NaN
# 1993-02-04  45.00000       NaN
# 1993-02-05  44.96875       NaN
# 1993-02-08  44.96875       NaN
# 1993-02-09  44.65625       NaN
# 1993-02-10  44.71875       NaN
# 1993-02-11  44.93750       NaN
# 1993-02-12  44.59375       NaN
# 1993-02-16  43.46875       NaN
# 1993-02-17  43.43750       NaN
# 1993-02-18  43.40625       NaN
# 1993-02-19  43.56250       NaN
# 1993-02-22  43.71875       NaN
# 1993-02-23  43.68750       NaN
# 1993-02-24  44.25000       NaN
# 1993-02-25  44.34375       NaN
# 1993-02-26  44.40625       NaN
# 1993-03-01  44.28125       NaN
# 1993-03-02  44.93750       NaN
# 1993-03-03  45.12500       NaN
# 1993-03-04  44.87500       NaN
# 1993-03-05  44.75000       NaN
# 1993-03-08  45.75000       NaN
# 1993-03-09  45.59375       NaN
# 1993-03-10  45.68750       NaN
# 1993-03-11  45.56250       NaN
# 1993-03-12  45.09375       NaN
# 1993-03-15  45.31250       NaN
# 1993-03-16  45.31250       NaN
# 1993-03-17  45.03125       NaN
# 1993-03-18  45.31250       NaN
# 1993-03-19  45.03125       NaN
# 1993-03-22  44.78125       NaN
# 1993-03-23  44.87500       NaN
# 1993-03-24  44.87500       NaN
# 1993-03-25  45.15625       NaN
# 1993-03-26  44.90625       NaN
# 1993-03-29  45.09375       NaN
# 1993-03-30  45.21875       NaN
# 1993-03-31  45.18750       NaN
# 1993-04-01  45.03125       NaN
# 1993-04-02  44.09375       NaN
# 1993-04-05  44.31250       NaN
# 1993-04-06  44.18750       NaN
# 1993-04-07  44.34375       NaN
# 1993-04-08  44.28125       NaN
# 1993-04-12  44.90625  44.68750
# 1993-04-13  45.00000  44.70875
# 1993-04-14  44.93750  44.72250

# %%
spy.plot(figsize=(8,5), fontsize=10)
plt.legend(loc='upper left', fontsize=10)
plt.show()

# %%
spy['EMA50'] = spy.Close.ewm(span=50, min_periods=50).mean()

# %%
spy
# Out:
#                  Close     SMA50       EMA50
# Date
# 1993-01-29   43.937500       NaN         NaN
# 1993-02-01   44.250000       NaN         NaN
# 1993-02-02   44.343750       NaN         NaN
# 1993-02-03   44.812500       NaN         NaN
# 1993-02-04   45.000000       NaN         NaN
# ...                ...       ...         ...
# 2023-12-22  473.649994  445.9060  452.640862
# 2023-12-26  475.649994  446.7890  453.543181
# 2023-12-27  476.510010  447.5984  454.443841
# 2023-12-28  476.690002  448.4118  455.316240
# 2023-12-29  475.309998  449.3138  456.100309
#
# [7786 rows x 3 columns]

# %%
spy.plot(figsize=(8,5), fontsize=10)
plt.legend(loc='upper left', fontsize=10)
plt.show()

# %%
spy['Day'] = spy.index.day_name()
spy['Quarter'] = spy.index.quarter

# %%
spy
# Out:
#                  Close     SMA50       EMA50        Day  Quarter
# Date
# 1993-01-29   43.937500       NaN         NaN     Friday        1
# 1993-02-01   44.250000       NaN         NaN     Monday        1
# 1993-02-02   44.343750       NaN         NaN    Tuesday        1
# 1993-02-03   44.812500       NaN         NaN  Wednesday        1
# 1993-02-04   45.000000       NaN         NaN   Thursday        1
# ...                ...       ...         ...        ...      ...
# 2023-12-22  473.649994  445.9060  452.640862     Friday        4
# 2023-12-26  475.649994  446.7890  453.543181    Tuesday        4
# 2023-12-27  476.510010  447.5984  454.443841  Wednesday        4
# 2023-12-28  476.690002  448.4118  455.316240   Thursday        4
# 2023-12-29  475.309998  449.3138  456.100309     Friday        4
#
# [7786 rows x 5 columns]

# %%
SPY = yf.download('SPY')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
SPY
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   24.840672
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   25.017353
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   25.070356
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   25.335375
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   25.441378
# ...                ...         ...         ...         ...         ...
# 2023-12-22  473.859985  475.380005  471.700012  473.649994  473.649994
# 2023-12-26  474.070007  476.579987  473.989990  475.649994  475.649994
# 2023-12-27  475.440002  476.660004  474.890015  476.510010  476.510010
# 2023-12-28  476.880005  477.549988  476.260010  476.690002  476.690002
# 2023-12-29  476.489990  477.029999  473.299988  475.309998  475.309998
#
#                Volume
# Date
# 1993-01-29    1003200
# 1993-02-01     480500
# 1993-02-02     201300
# 1993-02-03     529400
# 1993-02-04     531500
# ...               ...
# 2023-12-22   67126600
# 2023-12-26   55387000
# 2023-12-27   68000300
# 2023-12-28   77158100
# 2023-12-29  122234100
#
# [7786 rows x 6 columns]

# %%
SPY
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   24.840672
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   25.017353
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   25.070356
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   25.335375
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   25.441378
# ...                ...         ...         ...         ...         ...
# 2023-12-22  473.859985  475.380005  471.700012  473.649994  473.649994
# 2023-12-26  474.070007  476.579987  473.989990  475.649994  475.649994
# 2023-12-27  475.440002  476.660004  474.890015  476.510010  476.510010
# 2023-12-28  476.880005  477.549988  476.260010  476.690002  476.690002
# 2023-12-29  476.489990  477.029999  473.299988  475.309998  475.309998
#
#                Volume
# Date
# 1993-01-29    1003200
# 1993-02-01     480500
# 1993-02-02     201300
# 1993-02-03     529400
# 1993-02-04     531500
# ...               ...
# 2023-12-22   67126600
# 2023-12-26   55387000
# 2023-12-27   68000300
# 2023-12-28   77158100
# 2023-12-29  122234100
#
# [7786 rows x 6 columns]

# %%
all_days = pd.date_range(start='2010-12-31', end='2020-01-01', freq='D')
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#                '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#                '2019-12-31', '2020-01-01'],
#               dtype='datetime64[ns]', length=3289, freq='D')

# 2020-01-01         NaN         NaN         NaN         NaN         NaN
#
#                  Volume
# 2010-12-31   91218900.0
# 2011-01-01  138725200.0
# 2011-01-02  138725200.0
# 2011-01-03  138725200.0
# 2011-01-04  137409700.0
# ...                 ...
# 2019-12-28   49729100.0
# 2019-12-29   49729100.0
# 2019-12-30   49729100.0
# 2019-12-31   57077300.0
# 2020-01-01          NaN
#
# [3289 rows x 6 columns]

# %% [markdown]
# ### 1 week data

# %%
SPY = yf.download('SPY', interval='1wk')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
SPY
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   24.840683
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.423708
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.211697
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   24.628670
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   25.105694
# ...                ...         ...         ...         ...         ...
# 2023-11-27  454.649994  459.649994  453.339996  459.100006  457.246155
# 2023-12-04  455.600006  460.750000  454.309998  460.200012  458.341705
# 2023-12-11  459.690002  473.730011  459.470001  469.329987  467.434814
# 2023-12-18  470.980011  475.899994  467.820007  473.649994  473.649994
# 2023-12-25  474.070007  477.549988  473.299988  475.309998  475.309998
#
#                Volume
# Date
# 1993-01-25    1003200
# 1993-02-01    2234800
# 1993-02-08    1159800
# 1993-02-15     998700
# 1993-02-22    1024300
# ...               ...
# 2023-11-27  344617600
# 2023-12-04  361425400
# 2023-12-11  486953100
# 2023-12-18  382852200
# 2023-12-25  419831774
#
# [1614 rows x 6 columns]

# %% [markdown]
# ### Cummulative returns, Drawdowns etc..

# %%
apple = yf.download('AAPL')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple = apple.Close.to_frame()

# %%
apple['d_returns'] = np.log(apple.div(apple.shift(1)))

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-12    0.128348        NaN
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# ...                ...        ...
# 2023-12-22  193.600006  -0.005563
# 2023-12-26  193.050003  -0.002845
# 2023-12-27  193.149994   0.000518
# 2023-12-28  193.580002   0.002224
# 2023-12-29  192.529999  -0.005439
#
# [10853 rows x 2 columns]

# %%
apple.dropna(inplace=True)
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2023-12-22  193.600006  -0.005563
# 2023-12-26  193.050003  -0.002845
# 2023-12-27  193.149994   0.000518
# 2023-12-28  193.580002   0.002224
# 2023-12-29  192.529999  -0.005439
#
# [10852 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# 7.313261988920681

# %%
np.exp(apple.d_returns.sum())
# Out:
# 1500.0624040436219

# %%
apple['cummreturns'] = apple.d_returns.cumsum().apply(np.exp)
apple
# Out:
#                  Close  d_returns  cummreturns
# Date
# 1980-12-15    0.121652  -0.053581     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261
# 1980-12-17    0.115513   0.024450     0.899998
# 1980-12-18    0.118862   0.028580     0.926092
# 1980-12-19    0.126116   0.059239     0.982610
# ...                ...        ...          ...
# 2023-12-22  193.600006  -0.005563  1508.399171
# 2023-12-26  193.050003  -0.002845  1504.113923
# 2023-12-27  193.149994   0.000518  1504.892983
# 2023-12-28  193.580002   0.002224  1508.243311
# 2023-12-29  192.529999  -0.005439  1500.062404
#
# [10852 rows x 3 columns]

# %%
apple.cummreturns.plot(figsize=(10, 8), title='APPL buy and hold', fontsize=10)
plt.show()

# %%
apple.d_returns.mean()*252
# Out:
# 0.1698251033180991

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# 0.45156763592339977

# %% [markdown]
# ### how to calculate drawdowns

# %%
apple['cummmax'] = apple.cummreturns.cummax()
apple
# Out:
#                  Close  d_returns  cummreturns      cummmax
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829
# 1980-12-17    0.115513   0.024450     0.899998     0.947829
# 1980-12-18    0.118862   0.028580     0.926092     0.947829
# 1980-12-19    0.126116   0.059239     0.982610     0.982610
# ...                ...        ...          ...          ...
# 2023-12-22  193.600006  -0.005563  1508.399171  1543.537972
# 2023-12-26  193.050003  -0.002845  1504.113923  1543.537972
# 2023-12-27  193.149994   0.000518  1504.892983  1543.537972
# 2023-12-28  193.580002   0.002224  1508.243311  1543.537972
# 2023-12-29  192.529999  -0.005439  1500.062404  1543.537972
#
# [10852 rows x 4 columns]

# %%
apple[['cummmax', 'cummreturns']].plot(figsize=(10,8), title='APPL buy and hold + cummmax', fontsize=10)
plt.show()

# %%
apple['drawdown'] = apple['cummmax'] - apple['cummreturns']
apple
# Out:
#                  Close  d_returns  cummreturns      cummmax   drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2023-12-22  193.600006  -0.005563  1508.399171  1543.537972  35.138800
# 2023-12-26  193.050003  -0.002845  1504.113923  1543.537972  39.424049
# 2023-12-27  193.149994   0.000518  1504.892983  1543.537972  38.644989
# 2023-12-28  193.580002   0.002224  1508.243311  1543.537972  35.294660
# 2023-12-29  192.529999  -0.005439  1500.062404  1543.537972  43.475568
#
# [10852 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# 444.02718404402026

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index=='2023-01-05')]
# Out:
#                  Close  d_returns  cummreturns      cummmax    drawdown
# Date
# 2023-01-05  125.019997  -0.010661   974.070524  1418.097708  444.027184

# %%
apple['drawdown%'] = (apple['cummmax'] - apple['cummreturns']) / apple['cummmax']
apple
# Out:
#                  Close  d_returns  cummreturns      cummmax   drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2023-12-22  193.600006  -0.005563  1508.399171  1543.537972  35.138800
# 2023-12-26  193.050003  -0.002845  1504.113923  1543.537972  39.424049
# 2023-12-27  193.149994   0.000518  1504.892983  1543.537972  38.644989
# 2023-12-28  193.580002   0.002224  1508.243311  1543.537972  35.294660
# 2023-12-29  192.529999  -0.005439  1500.062404  1543.537972  43.475568
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# 1980-12-17   0.050464
# 1980-12-18   0.022934
# 1980-12-19   0.000000
# ...               ...
# 2023-12-22   0.022765
# 2023-12-26   0.025541
# 2023-12-27   0.025037
# 2023-12-28   0.022866
# 2023-12-29   0.028166
#
# [10852 rows x 6 columns]

# %%
apple['drawdown%'].max()
# Out:
# 0.82216567924191

# %%
apple['drawdown%'].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[(apple.index=='1997-12-23')]
# Out:
#                Close  d_returns  cummreturns   cummmax  drawdown  drawdown%
# Date
# 1997-12-23  0.115513   -0.02858     0.899998  5.060882  4.160883   0.822166

# %% [markdown]
# ### SMA Strategy

# %%
data = apple.Close.loc[(apple.index>='1991-01-01')]

# %%
data
# Out:
# Date
# 1991-01-02      0.388393
# 1991-01-03      0.383929
# 1991-01-04      0.386161
# 1991-01-07      0.386161
# 1991-01-08      0.386161
#                  ...
# 2023-12-22    193.600006
# 2023-12-26    193.050003
# 2023-12-27    193.149994
# 2023-12-28    193.580002
# 2023-12-29    192.529999
# Name: Close, Length: 8312, dtype: float64

# %%
data = data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2023-12-22  193.600006
# 2023-12-26  193.050003
# 2023-12-27  193.149994
# 2023-12-28  193.580002
# 2023-12-29  192.529999
#
# [8312 rows x 1 columns]

# %%
sma_s = 50
sma_l = 100

# %%
data['sma_s'] = data.Close.rolling(sma_s).mean()
data['sma_l'] = data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-01-02    0.388393         NaN         NaN
# 1991-01-03    0.383929         NaN         NaN
# 1991-01-04    0.386161         NaN         NaN
# 1991-01-07    0.386161         NaN         NaN
# 1991-01-08    0.386161         NaN         NaN
# ...                ...         ...         ...
# 2023-12-22  193.600006  185.398801  181.768301
# 2023-12-26  193.050003  185.682801  181.787101
# 2023-12-27  193.149994  185.971400  181.898701
# 2023-12-28  193.580002  186.300001  182.046001
# 2023-12-29  192.529999  186.633801  182.173301
#
# [8312 rows x 3 columns]

# %%
data.loc['2016'].plot(figsize=(10,8), title=f'AAPL - SMA{sma_s} | SMA{sma_l}', fontsize=10)
plt.show()

# %%
data.dropna(inplace=True)
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.402902    0.534420    0.513326
# 1991-05-24    0.409598    0.530960    0.513538
# 1991-05-28    0.410714    0.527344    0.513806
# 1991-05-29    0.419643    0.523638    0.514141
# 1991-05-30    0.425223    0.519732    0.514531
# ...                ...         ...         ...
# 2023-12-22  193.600006  185.398801  181.768301
# 2023-12-26  193.050003  185.682801  181.787101
# 2023-12-27  193.149994  185.971400  181.898701
# 2023-12-28  193.580002  186.300001  182.046001
# 2023-12-29  192.529999  186.633801  182.173301
#
# [8213 rows x 3 columns]

# %%
data['position'] = np.where(data['sma_s'] > data['sma_l'], 1, -1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1
# 1991-05-24    0.409598    0.530960    0.513538         1
# 1991-05-28    0.410714    0.527344    0.513806         1
# 1991-05-29    0.419643    0.523638    0.514141         1
# 1991-05-30    0.425223    0.519732    0.514531         1
# ...                ...         ...         ...       ...
# 2023-12-22  193.600006  185.398801  181.768301         1
# 2023-12-26  193.050003  185.682801  181.787101         1
# 2023-12-27  193.149994  185.971400  181.898701         1
# 2023-12-28  193.580002  186.300001  182.046001         1
# 2023-12-29  192.529999  186.633801  182.173301         1
#
# [8213 rows x 4 columns]

# %%
data.loc['2023', ['sma_s', 'sma_l', 'position']].plot(figsize=(10,8), title=f'AAPL - SMA{sma_s} | SMA{sma_l}', fontsize=10, secondary_y='position')
plt.show()

# %%
data['returnsb&h'] = np.log(data.Close.div(data.Close.shift(1)))
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1         NaN
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209
# ...                ...         ...         ...       ...         ...
# 2023-12-22  193.600006  185.398801  181.768301         1   -0.005563
# 2023-12-26  193.050003  185.682801  181.787101         1   -0.002845
# 2023-12-27  193.149994  185.971400  181.898701         1    0.000518
# 2023-12-28  193.580002  186.300001  182.046001         1    0.002224
# 2023-12-29  192.529999  186.633801  182.173301         1   -0.005439
#
# [8213 rows x 5 columns]

# %%
data['strategy'] = data['returnsb&h'] * data.position.shift(1)
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  strategy
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1         NaN       NaN
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209  0.013209
# ...                ...         ...         ...       ...         ...       ...
# 2023-12-22  193.600006  185.398801  181.768301         1   -0.005563 -0.005563
# 2023-12-26  193.050003  185.682801  181.787101         1   -0.002845 -0.002845
# 2023-12-27  193.149994  185.971400  181.898701         1    0.000518  0.000518
# 2023-12-28  193.580002  186.300001  182.046001         1    0.002224  0.002224
# 2023-12-29  192.529999  186.633801  182.173301         1   -0.005439 -0.005439
#
# [8213 rows x 6 columns]

# %%
data.dropna(inplace=True)

# %%
data[['returnsb&h', 'strategy']].sum()
# Out:
# returnsb&h    6.169314
# strategy      1.960008
# dtype: float64

# %%
data[['returnsb&h', 'strategy']].sum().apply(np.exp) # what 1$ will be
# Out:
# returnsb&h    477.858128
# strategy        7.099383
# dtype: float64

# %%
data[['returnsb&h', 'strategy']].std()*np.sqrt(252) #annual std
# Out:
# returnsb&h    0.434930
# strategy      0.435077
# dtype: float64

# %%
data.Close.plot(figsize=(10,8))
plt.show()

# %% [markdown]
# ## Strategy adjusted with long bias

# %%
data['position2'] = np.where(data['sma_s'] > data['sma_l'], 1, 0)

# %%
data['strategy2'] = data['returnsb&h'] * data.position2.shift(1)

# %%
data.dropna(inplace=True)

# %%
data[['returnsb&h', 'strategy2']].sum()
# Out:
# returnsb&h    6.152831
# strategy2     4.048178
# dtype: float64

# %%
data[['returnsb&h', 'strategy2']].sum().apply(np.exp)
# Out:
# returnsb&h    470.046246
# strategy2      57.292978
# dtype: float64

# %%
data[['returnsb&h', 'strategy2']].std()*np.sqrt(252)
# Out:
# returnsb&h    0.434947
# strategy2     0.336212
# dtype: float64

# %% [markdown]
# ## Strategy2 is better than strategy

# %%
data[['strategy', 'strategy2']].std()*np.sqrt(252)
# Out:
# strategy     0.435094
# strategy2    0.336212
# dtype: float64

# %%
def test_strategy(stock, start, end, SMA):
    df = yf.download(stock, start=start, end=end)
    data = df.Close.to_frame()
    data['returns'] = np.log(data.Close.div(data.Close.shift(1)))
    data['SMA_S'] = data.Close.rolling(int(SMA[0])).mean()
    data['SMA_L'] = data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)

    data['position'] = np.where(data['SMA_S'] > data['SMA_L'], 1, -1)
    data['strategy'] = data['returns']*data.position.shift(1)
    data.dropna(inplace=True)
    ret = np.exp(data['strategy'].sum())
    std = data['strategy'].std()*np.sqrt(252)
    return ret, std

# %%
test_strategy('NVDA', '2000-01-01', '2023-01-01', (50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (128.8259480097096, 0.5712158253875721)

# %% [markdown]
# ## Importing the class we made

# %%
from smbacktest import SMABacktester

# %%
tester = SMABacktester('NIO', 50, 100, '2000-01-01', '2023-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (5.686775, 4.449465)

# %%
tester.plot_results()
